# %%
import json

# %%
def read_json(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    return data

data = read_json("AdaCBMCode/AdaCBM/gpt_concepts/NCT-CRC-HE.json")
for key, value in data.items(): 
    print(f"{key}: {len(value)}")
# Out:
# ADI: 119
# BACK: 117
# DEB: 100
# LYM: 94
# MUC: 98
# MUS: 92
# NORM: 104
# STR: 96
# TUM: 104
