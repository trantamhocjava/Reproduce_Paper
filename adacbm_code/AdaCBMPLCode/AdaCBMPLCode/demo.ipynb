# %% [markdown]
# # Import

# %%
from gpt_concepts.concept_dataset import isic2018_concept_dataset
import numpy as np

# %%
num_concept = sum([len(concepts) for concepts in isic2018_concept_dataset.values()])
num_concept
# Out:
# 760

# %%
np.floor(4.5)
# Out:
# np.float64(4.0)
