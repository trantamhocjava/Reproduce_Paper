# %% [markdown]
# # import

# %%
import torch
from kltn_utils import

# %%
data = torch.load(
    "cp.pth", map_location="cpu", weights_only=False
)

data.keys()
# Out:
# dict_keys(['x', 'y'])

# %%
data["x"].shape
# Out:
# torch.Size([5, 10])
