# %% [markdown]
# # import

# %%
# !pip install -r /kaggle/input/datasets/tmtrnhelloworld/hybridcbmplcode/requirements.txt

import numpy as np
import time
from kltn_utils import kltn_utils
# Out:
# ...
#   Cloning https://github.com/trantamhocjava/kltn_utils.git to /tmp/pip-req-build-mw7wbqz8
#   Running command git clone --filter=blob:none --quiet https://github.com/trantamhocjava/kltn_utils.git /tmp/pip-req-build-mw7wbqz8
#   Resolved https://github.com/trantamhocjava/kltn_utils.git to commit 4af03c2a344fa5f4ba6e9991f2a5444eaff3fc3f
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 13.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.2/869.2 kB 29.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 10.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Adacbm, ViT-L-14

# %% [markdown]
# adacbmAlgo-ViTL14

# %%
config = {
  "cp_path": "/kaggle/working/checkpoint",
  "clip_model": "ViT-L-14",
  "transform": "uniform",
  "dataset_dir": "/kaggle/input/datasets/tmtrnhelloworld/isic2018splittedv1",
  "dataset_name": "isic2018",
  "batch_size": 128,
  "select_concept_method": "adacbm",
  "num_select_concepts": 350,
  "weight": 0.9
}

config_path = "/kaggle/working/config.json"
kltn_utils.save_dict_to_json(config, config_path)
# !PYTHONPATH=/kaggle/input/datasets/tmtrnhelloworld python -m hybridcbmplcode.run.run_select_concept.run_select_concept \
--arg_json {config_path}

# %% [markdown]
# # Submodular, ViT-L-14

# %% [markdown]
# submodular-ViTL14

# %%
config = {
  "cp_path": "/kaggle/working/checkpoint_sub",
  "clip_model": "ViT-L-14",
  "transform": "uniform",
  "dataset_dir": "/kaggle/input/datasets/tmtrnhelloworld/isic2018splittedv1",
  "dataset_name": "isic2018",
  "batch_size": 512,
  "select_concept_method": "submodular",
  "num_select_concepts": 350,
  "weight": [1e7, 0.1]
}

config_path = "/kaggle/working/config.json"
kltn_utils.save_dict_to_json(config, config_path)
# !PYTHONPATH=/kaggle/input/datasets/tmtrnhelloworld python -m hybridcbmplcode.run.run_select_concept.run_select_concept \
--arg_json {config_path}
# Out:
# Run select concept
#
# Seed set to 42
#
# Load CLIP model
# open_clip_model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#
# Load img feat in train dataset
#
#
# run batch 1 / 12
#
#
# run batch 2 / 12
#
#
# run batch 3 / 12
#
#
# run batch 4 / 12
#
#
# run batch 5 / 12
#
#
# run batch 6 / 12
#
#
# run batch 7 / 12
#
#
# run batch 8 / 12
#
#
# run batch 9 / 12
#
#
# run batch 10 / 12
#
#
# run batch 11 / 12
#
#
# run batch 12 / 12
#
#
# Load img feat in train dataset, time: 313.63108491897583 (s)
#
#
# Load concept feat
#
#
# run batch 1 / 2
#
#
# run batch 2 / 2
#
#
# Load concept feat, time: 3.6646206378936768 (s)
#
#
# Load class feat
#
#
# run batch 1 / 1
#
#
# get selected concept idx
#
#
# Save selected concepts
#
#
# Done

# %% [markdown]
# # Adacbm, hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224.orig_in21k

# %% [markdown]
# adacbm-BiomedCLIP-PubMedBERT256

# %%
config = {
  "cp_path": "/kaggle/working/checkpoint_bio",
  "clip_model": "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224.orig_in21k",
  "transform": "uniform",
  "dataset_dir": "/kaggle/input/datasets/tmtrnhelloworld/isic2018splittedv1",
  "dataset_name": "isic2018",
  "batch_size": 512,
  "select_concept_method": "adacbm",
  "num_select_concepts": 350,
  "weight": 0.9
}

config_path = "/kaggle/working/config.json"
kltn_utils.save_dict_to_json(config, config_path)
# !PYTHONPATH=/kaggle/input/datasets/tmtrnhelloworld python -m hybridcbmplcode.run.run_select_concept.run_select_concept \
--arg_json {config_path}
# Out:
# Run select concept
#
# Seed set to 42
#
# Load CLIP model
#
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# open_clip_config.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/784M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# replace visual encoder weight
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# Load img feat in train dataset
#
#
# run batch 1 / 12
#
#
# run batch 2 / 12
#
#
# run batch 3 / 12
#
#
# run batch 4 / 12
#
#
# run batch 5 / 12
#
#
# run batch 6 / 12
#
#
# run batch 7 / 12
#
#
# run batch 8 / 12
#
#
# run batch 9 / 12
#
#
# run batch 10 / 12
#
#
# run batch 11 / 12
#
#
# run batch 12 / 12
#
#
# ...

# %% [markdown]
# # AdaCBM, hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224

# %% [markdown]
# adacbm-BiomedCLIP-PubMedBERT256-ORG

# %%
config = {
  "cp_path": "/kaggle/working/checkpoint_bio",
  "clip_model": "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224",
  "transform": "uniform",
  "dataset_dir": "/kaggle/input/datasets/tmtrnhelloworld/isic2018splittedv1",
  "dataset_name": "isic2018",
  "batch_size": 512,
  "select_concept_method": "adacbm",
  "num_select_concepts": 350,
  "weight": 0.9
}

config_path = "/kaggle/working/config.json"
kltn_utils.save_dict_to_json(config, config_path)
# !PYTHONPATH=/kaggle/input/datasets/tmtrnhelloworld python -m hybridcbmplcode.run.run_select_concept.run_select_concept \
--arg_json {config_path}
# Out:
# Seed set to 42
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# open_clip_config.json: 100%|███████████████████| 707/707 [00:00<00:00, 3.50MB/s]
# open_clip_pytorch_model.bin:  43%|████▋      | 335M/784M [00:04<00:06, 72.2MB/s]
# config.json: 100%|█████████████████████████████| 385/385 [00:00<00:00, 2.30MB/s]
# tokenizer_config.json: 100%|██████████████████| 28.0/28.0 [00:00<00:00, 191kB/s]
# vocab.txt: 225kB [00:00, 14.9MB/s]
#
# run batch 1 / 12
#
#
# run batch 2 / 12
#
#
# run batch 3 / 12
#
#
# run batch 4 / 12
#
#
# run batch 5 / 12
#
#
# run batch 6 / 12
#
#
# run batch 7 / 12
#
#
# run batch 8 / 12
#
#
# run batch 9 / 12
#
#
# run batch 10 / 12
#
#
# run batch 11 / 12
#
#
# run batch 12 / 12
#
#
# run batch 1 / 2
#
#
# run batch 2 / 2
#
#
# run batch 1 / 1
#
#
# img_feat.shape: torch.Size([6009, 512])
#
#
# concept_feat.shape: torch.Size([733, 512])
# ...

# %% [markdown]
# # Submodular, hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224

# %% [markdown]
# submodular-BiomedCLIP-PubMedBERT256-ORG

# %%
config = {
  "cp_path": "/kaggle/working/checkpoint_sub",
  "clip_model": "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224",
  "transform": "uniform",
  "dataset_dir": "/kaggle/input/datasets/tmtrnhelloworld/isic2018splittedv1",
  "dataset_name": "isic2018",
  "batch_size": 512,
  "select_concept_method": "submodular",
  "num_select_concepts": 350,
  "weight": [1e7, 0.1]
}

config_path = "/kaggle/working/config.json"
kltn_utils.save_dict_to_json(config, config_path)
# !PYTHONPATH=/kaggle/input/datasets/tmtrnhelloworld python -m hybridcbmplcode.run.run_select_concept.run_select_concept \
--arg_json {config_path}
# Out:
# Seed set to 42
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# run batch 1 / 12
#
#
# run batch 2 / 12
#
#
# run batch 3 / 12
#
#
# run batch 4 / 12
#
#
# run batch 5 / 12
#
#
# run batch 6 / 12
#
#
# run batch 7 / 12
#
#
# run batch 8 / 12
#
#
# run batch 9 / 12
#
#
# run batch 10 / 12
#
#
# run batch 11 / 12
#
#
# run batch 12 / 12
#
#
# run batch 1 / 2
#
#
# run batch 2 / 2
#
#
# run batch 1 / 1
#
#
# DONE

# %% [markdown]
# # Submodular, hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224.orig_in21k

# %% [markdown]
# submodular-BiomedCLIP-PubMedBERT256

# %%
config = {
  "cp_path": "/kaggle/working/checkpoint_new",
  "clip_model": "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224.orig_in21k",
  "transform": "uniform",
  "dataset_dir": "/kaggle/input/datasets/tmtrnhelloworld/isic2018splittedv1",
  "dataset_name": "isic2018",
  "batch_size": 512,
  "select_concept_method": "submodular",
  "num_select_concepts": 350,
  "weight": [1e7, 0.1]
}

config_path = "/kaggle/working/config.json"
kltn_utils.save_dict_to_json(config, config_path)
# !PYTHONPATH=/kaggle/input/datasets/tmtrnhelloworld python -m hybridcbmplcode.run.run_select_concept.run_select_concept \
--arg_json {config_path}
# Out:
# Seed set to 42
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# replace visual encoder weight
#
# model.safetensors: 100%|█████████████████████| 343M/343M [00:05<00:00, 58.8MB/s]
#
# run batch 1 / 12
#
#
# run batch 2 / 12
#
#
# run batch 3 / 12
#
#
# run batch 4 / 12
#
#
# run batch 5 / 12
#
#
# run batch 6 / 12
#
#
# run batch 7 / 12
#
#
# run batch 8 / 12
#
#
# run batch 9 / 12
#
#
# run batch 10 / 12
#
#
# run batch 11 / 12
#
#
# run batch 12 / 12
#
#
# run batch 1 / 2
#
#
# run batch 2 / 2
#
#
# run batch 1 / 1
#
#
# DONE
