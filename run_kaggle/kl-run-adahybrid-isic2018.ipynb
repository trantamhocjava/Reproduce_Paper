# %% [markdown]
# # import

# %%
# !pip install -r /kaggle/input/datasets/tmtrnhelloworld/hybridcbmplcode/requirements.txt

import numpy as np
import time
import pandas as pd 
from kltn_utils import kltn_utils
# Out:
# ...
#   Cloning https://github.com/trantamhocjava/kltn_utils.git to /tmp/pip-req-build-6ndb4_o1
#   Running command git clone --filter=blob:none --quiet https://github.com/trantamhocjava/kltn_utils.git /tmp/pip-req-build-6ndb4_o1
#   Resolved https://github.com/trantamhocjava/kltn_utils.git to commit 4af03c2a344fa5f4ba6e9991f2a5444eaff3fc3f
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 14.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.2/869.2 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 50.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 97.1 MB/s eta 0:00:00:00:010:01
# ...

# %% [markdown]
# # Run 1 epoch

# %%
config = {
    "mode": "train",
    "last_state": None,
    "cp_path": "/kaggle/working/checkpoint",
    "select_concept_data_path": "/kaggle/input/datasets/tmtrnhelloworld/adacbm-biomedclip-pubmedbert256/select_concept_data.pth",
    "dataset_name": "isic2018",
    "dataset_dir": "/kaggle/input/datasets/tmtrnhelloworld/isic2018splittedv1",
    "transform": "uniform",
    "monitor": "val_y_bmac",
    "start_epoch": 1,
    "end_epoch": 1,
    "batch_size": 128,
    "optimizer": {"optimizer": "adamw", "lr": 0.0001},
    "amp": True,
    "loss": {
        "lambda_discri": 1,
        "lambda_ort": 0.1,
        "lambda_align": 0.01,
        "lambda_cls": 1,
        "lambda_concept": 1,
    },
    "model": {
        "clip_model": "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224.orig_in21k",
        "scale": 0.1,
        "num_dynamic_concept": 35,
        "num_ada_layer": 2,
    },
}


config_path = "/kaggle/working/config.json"
kltn_utils.save_dict_to_json(config, config_path)
# !PYTHONPATH=/kaggle/input/datasets/tmtrnhelloworld python -m hybridcbmplcode.run.train_ada_hybridcbm.train_ada_hybridcbm \
--arg_json {config_path} 

config = {
    "mode": "test",
    "best_model": "/kaggle/working/checkpoint/best.ckpt",
    "cp_path": "/kaggle/working/checkpoint",
    "select_concept_data_path": "/kaggle/input/datasets/tmtrnhelloworld/adacbm-biomedclip-pubmedbert256/select_concept_data.pth",
    "dataset_name": "isic2018",
    "dataset_dir": "/kaggle/input/datasets/tmtrnhelloworld/isic2018splittedv1",
    "transform": "uniform",
    "monitor": "val_y_bmac",
    "start_epoch": 1,
    "end_epoch": 1,
    "batch_size": 128,
    "optimizer": {"optimizer": "adamw", "lr": 0.0001},
    "amp": True,
    "loss": {
        "lambda_discri": 1,
        "lambda_ort": 0.1,
        "lambda_align": 0.01,
        "lambda_cls": 1,
        "lambda_concept": 1,
    },
    "model": {
        "clip_model": "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224.orig_in21k",
        "scale": 0.1,
        "num_dynamic_concept": 35,
        "num_ada_layer": 2,
    },
}


config_path = "/kaggle/working/config.json"
kltn_utils.save_dict_to_json(config, config_path)
# !PYTHONPATH=/kaggle/input/datasets/tmtrnhelloworld python -m hybridcbmplcode.run.train_ada_hybridcbm.train_ada_hybridcbm \
--arg_json {config_path} 

metric = pd.read_csv("/kaggle/working/checkpoint/metrics.csv")
print(metric)
# Out:
# Seed set to 42
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# replace visual encoder weight
#
#
# replace visual encoder weight
#
#
# replace visual encoder weight
#
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# [rank: 1] Seed set to 42
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ...
