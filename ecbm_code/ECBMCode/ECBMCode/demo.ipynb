# %%
import pandas as pd
import torch

a = pd.DataFrame({
    "A": [[1,0,1], [0,1,0], [1,1,1]],
    "B": [5,6,7]
})



a["A"] = a["A"].apply(torch.tensor)

shape = a["A"].apply(lambda x: x.shape)
shape
# Out:
# 0    (3,)
# 1    (3,)
# 2    (3,)
# Name: A, dtype: object
